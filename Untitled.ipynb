# %%
import numpy as np

# %%
n = 3

# %%
2 ** n
# Out:
# 8

# %%
120
# Out:
# 120

# %%
2 ** 7
# Out:
# 128

# %%
x = 5

# %%
np.int8
# Out:
# numpy.int8

# %% [markdown]
# ![numpy.png](attachment:5bbaee93-2b7e-4b91-8b1f-3da2079b5b3d.png)![numpy](numpy.png)
